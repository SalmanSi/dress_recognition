# %%
from PIL import Image
import imagehash
import matplotlib.pyplot as plt
import os

# %%
hashfunc=imagehash.average_hash

# %%
image=Image.open(r"C:\Users\admin\Desktop\dress recognition\clothes-dataset.v2-2022-12-03-7-51pm.clip\test\short-sleeve\images (5).jpeg")
plt.imshow(image)
ref_image_hash=hashfunc(image)
print(ref_image_hash)
# Out:
# f7ebe3c3c1830000

# %%
print(f"distance={ref_image_hash-image_hash_orig}")
# Out:
# distance=15

# %%
# compute hash of all images in train directory
train_hashes=[]
parent_dir = r'C:\Users\admin\Desktop\dress recognition\clothes-dataset.v2-2022-12-03-7-51pm.clip\train'
images = []
for image_dir in os.listdir(parent_dir):
    image_dir=os.path.join(parent_dir,image_dir)
    image_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith(('jpg', 'png', 'jpeg'))]

    
    for image_file in image_files:
        image = Image.open(image_file)
        hash=(hashfunc(image))
        images.append((image_file, image,hash))

# %%
print(len(images))
# Out:
# 344

# %%
# find min hash / most similar picture
import sys
min_distace=sys.maxsize
i=0
for image_file,image,hash in images:
    if (hash-ref_image_hash)<min_distace:
        min_distace=(hash-ref_image_hash)
        print(min_distace)
        matching_image=image
        plt.figure()
        plt.imshow(image)
        plt.title(f"Image {i+1}")
        plt.axis('off')  # Turn off the axis
        plt.show()
        i+=1
# Out:
# 17
# 14
# 13
# 9

# %%
matching_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>
